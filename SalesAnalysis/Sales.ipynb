# %%
import pandas as pd
import os

# %%
pwd = os.getcwd()
path = pwd + '/Sales_Data/'

# %% [markdown]
# ## Importing several csv files and concat them

# %%
files = [file for file in os.listdir(path)]
all_months_data = pd.DataFrame()

for file in files:
    df = pd.read_csv(path + file)
    all_months_data = pd.concat([all_months_data, df])

all_months_data
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       162009                      iPhone                1        700
# 1       162009    Lightning Charging Cable                1      14.95
# 2       162009            Wired Headphones                2      11.99
# 3       162010  Bose SoundSport Headphones                1      99.99
# 4       162011      34in Ultrawide Monitor                1     379.99
# ...        ...                         ...              ...        ...
# 16630   209916  Bose SoundSport Headphones                1      99.99
# 16631   209917            Wired Headphones                1      11.99
# 16632   209918      AAA Batteries (4-pack)                2       2.99
# 16633   209919        USB-C Charging Cable                1      11.95
# 16634   209920             ThinkPad Laptop                1     999.99
#
#            Order Date                      Purchase Address
# ...

# %% [markdown]
# ## Adding Month column

# %%
data = all_months_data.copy()

# %%
data['Month'] = data['Order Date'].str[0:2]
data
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       162009                      iPhone                1        700
# 1       162009    Lightning Charging Cable                1      14.95
# 2       162009            Wired Headphones                2      11.99
# 3       162010  Bose SoundSport Headphones                1      99.99
# 4       162011      34in Ultrawide Monitor                1     379.99
# ...        ...                         ...              ...        ...
# 16630   209916  Bose SoundSport Headphones                1      99.99
# 16631   209917            Wired Headphones                1      11.99
# 16632   209918      AAA Batteries (4-pack)                2       2.99
# 16633   209919        USB-C Charging Cable                1      11.95
# 16634   209920             ThinkPad Laptop                1     999.99
#
#            Order Date                      Purchase Address Month
# ...

# %% [markdown]
# ## Lets clean the data to remove NaN

# %%
data = data.dropna(how='all')
data[data['Month'].isna()]
# Out:
# Empty DataFrame
# Columns: [Order ID, Product, Quantity Ordered, Price Each, Order Date, Purchase Address, Month]
# Index: []

# %% [markdown]
# ### We have the column names duplicated throughtout the data because we concatenated several cssv files that had them as the first row.

# %%
data[data['Order Date'].str[0:2] == 'Or']
# Out:
#        Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# 433    Order ID  Product  Quantity Ordered  Price Each  Order Date
# 864    Order ID  Product  Quantity Ordered  Price Each  Order Date
# 930    Order ID  Product  Quantity Ordered  Price Each  Order Date
# 1979   Order ID  Product  Quantity Ordered  Price Each  Order Date
# 2032   Order ID  Product  Quantity Ordered  Price Each  Order Date
# ...         ...      ...               ...         ...         ...
# 14291  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 15419  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 15963  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 16234  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 16505  Order ID  Product  Quantity Ordered  Price Each  Order Date
#
#        Purchase Address Month
# 433    Purchase Address    Or
# 864    Purchase Address    Or
# 930    Purchase Address    Or
# 1979   Purchase Address    Or
# ...

# %%
data = data[data['Order Date'].str[0:2] != 'Or']

# %%
data['Month']=data['Month'].astype('int32')
data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   162009                      iPhone                1        700
# 1   162009    Lightning Charging Cable                1      14.95
# 2   162009            Wired Headphones                2      11.99
# 3   162010  Bose SoundSport Headphones                1      99.99
# 4   162011      34in Ultrawide Monitor                1     379.99
#
#        Order Date                      Purchase Address  Month
# 0  03/28/19 20:59       942 Church St, Austin, TX 73301      3
# 1  03/28/19 20:59       942 Church St, Austin, TX 73301      3
# 2  03/28/19 20:59       942 Church St, Austin, TX 73301      3
# 3  03/17/19 05:39  261 10th St, San Francisco, CA 94016      3
# 4  03/10/19 00:01  764 13th St, San Francisco, CA 94016      3

# %% [markdown]
# ## Add a Sales column

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 185950 entries, 0 to 16634
# Data columns (total 7 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185950 non-null  object
#  1   Product           185950 non-null  object
#  2   Quantity Ordered  185950 non-null  object
#  3   Price Each        185950 non-null  object
#  4   Order Date        185950 non-null  object
#  5   Purchase Address  185950 non-null  object
#  6   Month             185950 non-null  int32
# dtypes: int32(1), object(6)
# memory usage: 10.6+ MB

# %% [markdown]
# ### We see that all columns are saved as 'object' and we need to convert some of them to numeric values in order to operate with them.

# %%
data['Quantity Ordered'] = pd.to_numeric(data['Quantity Ordered'])
data['Price Each'] = pd.to_numeric(data['Price Each'])

# %%
data['Sales'] = data['Quantity Ordered']*data['Price Each']
data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   162009                      iPhone                 1      700.00
# 1   162009    Lightning Charging Cable                 1       14.95
# 2   162009            Wired Headphones                 2       11.99
# 3   162010  Bose SoundSport Headphones                 1       99.99
# 4   162011      34in Ultrawide Monitor                 1      379.99
#
#        Order Date                      Purchase Address  Month   Sales
# 0  03/28/19 20:59       942 Church St, Austin, TX 73301      3  700.00
# 1  03/28/19 20:59       942 Church St, Austin, TX 73301      3   14.95
# 2  03/28/19 20:59       942 Church St, Austin, TX 73301      3   23.98
# 3  03/17/19 05:39  261 10th St, San Francisco, CA 94016      3   99.99
# 4  03/10/19 00:01  764 13th St, San Francisco, CA 94016      3  379.99

# %% [markdown]
# # Question 1: What was the best month for sales? How much was earned that month?

# %%
results = data.groupby('Month').sum()
results
# Out:
#        Quantity Ordered  Price Each       Sales
# Month
# 1                 10903  1811768.38  1822256.73
# 2                 13449  2188884.72  2202022.42
# 3                 17005  2791207.83  2807100.38
# 4                 20558  3367671.02  3390670.24
# 5                 18667  3135125.13  3152606.75
# 6                 15253  2562025.61  2577802.26
# 7                 16072  2632539.56  2647775.76
# 8                 13448  2230345.42  2244467.88
# 9                 13109  2084992.09  2097560.13
# 10                22703  3715554.83  3736726.88
# 11                19798  3180600.68  3199603.20
# 12                28114  4588415.41  4613443.34

# %%
import matplotlib.pyplot as plt

plt.bar(range(1,13),results['Sales'])
plt.xticks(range(1,13))
plt.xlabel('Month number')
plt.ylabel('Sales in USD')
plt.show()

# %% [markdown]
# # Question 2: What city had the highest number of sales?

# %% [markdown]
# ### First we have to make a city column

# %%
data['City'] = data['Purchase Address'].apply(lambda x: x.split(',')[1] + ' (' + x.split(',')[2].split(' ')[1] + ')')
data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   162009                      iPhone                 1      700.00
# 1   162009    Lightning Charging Cable                 1       14.95
# 2   162009            Wired Headphones                 2       11.99
# 3   162010  Bose SoundSport Headphones                 1       99.99
# 4   162011      34in Ultrawide Monitor                 1      379.99
#
#        Order Date                      Purchase Address  Month   Sales  \
# 0  03/28/19 20:59       942 Church St, Austin, TX 73301      3  700.00
# 1  03/28/19 20:59       942 Church St, Austin, TX 73301      3   14.95
# 2  03/28/19 20:59       942 Church St, Austin, TX 73301      3   23.98
# 3  03/17/19 05:39  261 10th St, San Francisco, CA 94016      3   99.99
# 4  03/10/19 00:01  764 13th St, San Francisco, CA 94016      3  379.99
#
#                   City
# 0          Austin (TX)
# 1          Austin (TX)
# 2          Austin (TX)
# 3   San Francisco (CA)
# ...

# %%
results2 = data.groupby('City').sum()
results2
# Out:
#                      Quantity Ordered  Price Each   Month       Sales
# City
#  Atlanta (GA)                   16602  2779908.20  104794  2795498.58
#  Austin (TX)                    11153  1809873.61   69829  1819581.75
#  Boston (MA)                    22528  3637409.77  141112  3661642.01
#  Dallas (TX)                    16730  2752627.82  104620  2767975.40
#  Los Angeles (CA)               33289  5421435.23  208325  5452570.80
#  New York City (NY)             27932  4635370.83  175741  4664317.43
#  Portland (ME)                   2750   447189.25   17144   449758.27
#  Portland (OR)                  11303  1860558.22   70621  1870732.34
#  San Francisco (CA)             50239  8211461.74  315520  8262203.91
#  Seattle (WA)                   16553  2733296.01  104941  2747755.48

# %%
import matplotlib.pyplot as plt
cities  = [city for city, df in data.groupby('City')]

plt.bar(cities,results2['Sales'])
plt.xticks(cities,rotation='vertical')
plt.xlabel('City name')
plt.ylabel('Sales in USD')
plt.show()

# %% [markdown]
# # Question 3: What time should we display advertisements to maximize the likelihood of costumer's buying product?

# %%
data['Order Date'] = pd.to_datetime(data['Order Date'])
data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   162009                      iPhone                 1      700.00
# 1   162009    Lightning Charging Cable                 1       14.95
# 2   162009            Wired Headphones                 2       11.99
# 3   162010  Bose SoundSport Headphones                 1       99.99
# 4   162011      34in Ultrawide Monitor                 1      379.99
#
#            Order Date                      Purchase Address  Month   Sales  \
# 0 2019-03-28 20:59:00       942 Church St, Austin, TX 73301      3  700.00
# 1 2019-03-28 20:59:00       942 Church St, Austin, TX 73301      3   14.95
# 2 2019-03-28 20:59:00       942 Church St, Austin, TX 73301      3   23.98
# 3 2019-03-17 05:39:00  261 10th St, San Francisco, CA 94016      3   99.99
# 4 2019-03-10 00:01:00  764 13th St, San Francisco, CA 94016      3  379.99
#
#                   City
# 0          Austin (TX)
# 1          Austin (TX)
# 2          Austin (TX)
# ...

# %%
data['Hour'] = data['Order Date'].dt.hour
data['Minute'] = data['Order Date'].dt.minute
data['Count'] = 1
data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   162009                      iPhone                 1      700.00
# 1   162009    Lightning Charging Cable                 1       14.95
# 2   162009            Wired Headphones                 2       11.99
# 3   162010  Bose SoundSport Headphones                 1       99.99
# 4   162011      34in Ultrawide Monitor                 1      379.99
#
#            Order Date                      Purchase Address  Month   Sales  \
# 0 2019-03-28 20:59:00       942 Church St, Austin, TX 73301      3  700.00
# 1 2019-03-28 20:59:00       942 Church St, Austin, TX 73301      3   14.95
# 2 2019-03-28 20:59:00       942 Church St, Austin, TX 73301      3   23.98
# 3 2019-03-17 05:39:00  261 10th St, San Francisco, CA 94016      3   99.99
# 4 2019-03-10 00:01:00  764 13th St, San Francisco, CA 94016      3  379.99
#
#                   City  Hour  Minute  Count
# 0          Austin (TX)    20      59      1
# ...

# %%
hours  = [hour for hour, df in data.groupby('Hour')]

plt.plot(hours,data.groupby('Hour').count()['Count'])
plt.xticks(hours)
plt.grid()
plt.xlabel("Hour")
plt.ylabel('Number of orders')
plt.show()

#Maybe put on ads at 10 am and 5 pm.

# %% [markdown]
# # Quesion 4: What products are most often sold together?

# %%
#If they have the same order ID, they were sold together.
df = data[data['Order ID'].duplicated(keep=False)]
df.head(10)
# Out:
#    Order ID                   Product  Quantity Ordered  Price Each  \
# 0    162009                    iPhone                 1      700.00
# 1    162009  Lightning Charging Cable                 1       14.95
# 2    162009          Wired Headphones                 2       11.99
# 30   162037                    iPhone                 1      700.00
# 31   162037  Lightning Charging Cable                 1       14.95
# 60   162066     AA Batteries (4-pack)                 1        3.84
# 61   162066      USB-C Charging Cable                 2       11.95
# 66   162071           Vareebadd Phone                 1      400.00
# 67   162071      USB-C Charging Cable                 1       11.95
# 78   162082           Vareebadd Phone                 1      400.00
#
#             Order Date                        Purchase Address  Month   Sales  \
# 0  2019-03-28 20:59:00         942 Church St, Austin, TX 73301      3  700.00
# ...

# %%
# Referenced: https://stackoverflow.com/questions/27298178/concatenate-strings-from-several-rows-using-pandas-groupby
df['Grouped'] = df.groupby('Order ID')['Product'].transform(lambda x: ','.join(x))
df2 = df[['Order ID', 'Grouped']].drop_duplicates()
df2.head()
#So the idea is to put all the items from the same order in a single column.
# Out:
# /tmp/ipykernel_11921/693574005.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Grouped'] = df.groupby('Order ID')['Product'].transform(lambda x: ','.join(x))
#    Order ID                                           Grouped
# 0    162009  iPhone,Lightning Charging Cable,Wired Headphones
# 30   162037                   iPhone,Lightning Charging Cable
# 60   162066        AA Batteries (4-pack),USB-C Charging Cable
# 66   162071              Vareebadd Phone,USB-C Charging Cable
# 78   162082                  Vareebadd Phone,Wired Headphones

# %%
# Referenced: https://stackoverflow.com/questions/52195887/counting-unique-pairs-of-numbers-into-a-python-dictionary
from itertools import combinations
from collections import Counter

count = Counter()

for row in df2['Grouped']:
    row_list = row.split(',')
    count.update(Counter(combinations(row_list, 2)))

for key,value in count.most_common(10):
    print(key, value)
# Out:
# ('iPhone', 'Lightning Charging Cable') 1005
# ('Google Phone', 'USB-C Charging Cable') 987
# ('iPhone', 'Wired Headphones') 447
# ('Google Phone', 'Wired Headphones') 414
# ('Vareebadd Phone', 'USB-C Charging Cable') 361
# ('iPhone', 'Apple Airpods Headphones') 360
# ('Google Phone', 'Bose SoundSport Headphones') 220
# ('USB-C Charging Cable', 'Wired Headphones') 160
# ('Vareebadd Phone', 'Wired Headphones') 143
# ('Lightning Charging Cable', 'Wired Headphones') 92

# %% [markdown]
# # QUestion 5: What product was sold the most? Why do you think it was?

# %%
product_group = data.groupby('Product')
quantity_ordered = product_group.sum()['Quantity Ordered']

keys = [pair for pair, df in product_group]
plt.bar(keys, quantity_ordered)
plt.xticks(keys, rotation='vertical', size=8)
plt.show()

# %% [markdown]
# #### Batteries were the most sold item and its probably becuase they are a high demand item. They have several uses and a very limited lifetime, so people have to replace them often.

# %%
# Referenced: https://stackoverflow.com/questions/14762181/adding-a-y-axis-label-to-secondary-y-axis-in-matplotlib

prices = data.groupby('Product').mean()['Price Each']

fig, ax1 = plt.subplots()

ax2 = ax1.twinx()
ax1.bar(keys, quantity_ordered, color='g')
ax2.plot(keys, prices, color='b')

ax1.set_xlabel('Product Name')
ax1.set_ylabel('Quantity Ordered', color='g')
ax2.set_ylabel('Price ($)', color='b')
ax1.set_xticklabels(keys, rotation='vertical', size=8)

fig.show()
# Out:
# /tmp/ipykernel_11921/3087214396.py:14: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(keys, rotation='vertical', size=8)
# /tmp/ipykernel_11921/3087214396.py:16: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
